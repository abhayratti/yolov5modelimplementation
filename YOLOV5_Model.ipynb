# %% [markdown]
# <a href="https://colab.research.google.com/github/abhayratti/yolov5modelimplementation/blob/main/YOLOV5_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Dependencies

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# %pip install -r requirements.txt

# %%
import torch 
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# %%
import os 
import time

# %% [markdown]
# *Images were captured and labeled locally*

# %%
# !python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --cache

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='runs/train/exp3/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-6-9 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7064065 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('colabdata', 'images', 'forward.fc536c9a-04c9-11ee-a096-c809a8cb063c.jpg')

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 480x640 1 forward
# Speed: 16.3ms pre-process, 325.4ms inference, 6.2ms NMS per image at shape (1, 3, 480, 640)

# %%
results.show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FCDA4203040>
